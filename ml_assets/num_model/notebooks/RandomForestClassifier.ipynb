# %%
import joblib
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv("../data/cloudburst_dataset.csv")
df
# Out:
#       Cloud_Top_Height  Cloud_Base_Height  Lightning_Count  Optical_Thickness  \
# 0         14102.922471        4478.254022       181.345045          81.458788
# 1         16280.349921        3282.266452       135.691187         100.754718
# 2         14610.191174        3540.533728       127.338520          79.712916
# 3         14442.462510        5226.559823       123.329536          68.037289
# 4         15792.328643        2259.156281       170.188910          65.791433
# ...                ...                ...              ...                ...
# 9995      12416.550137        4418.751713        43.000581          39.545973
# 9996      15214.536284        4427.930940        44.759519          30.847472
# 9997      12942.719214        1080.787694        20.691230          58.312846
# 9998      14245.382958        3919.624936        72.545314          45.259220
# 9999      15378.079626        3163.485237        33.594557          44.678716
#
# ...

# %%
X = df.drop(columns=["cloud_burst", "source_type"])
y = df["cloud_burst"]
X
# Out:
#       Cloud_Top_Height  Cloud_Base_Height  Lightning_Count  Optical_Thickness  \
# 0         14102.922471        4478.254022       181.345045          81.458788
# 1         16280.349921        3282.266452       135.691187         100.754718
# 2         14610.191174        3540.533728       127.338520          79.712916
# 3         14442.462510        5226.559823       123.329536          68.037289
# 4         15792.328643        2259.156281       170.188910          65.791433
# ...                ...                ...              ...                ...
# 9995      12416.550137        4418.751713        43.000581          39.545973
# 9996      15214.536284        4427.930940        44.759519          30.847472
# 9997      12942.719214        1080.787694        20.691230          58.312846
# 9998      14245.382958        3919.624936        72.545314          45.259220
# 9999      15378.079626        3163.485237        33.594557          44.678716
#
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = RandomForestClassifier()

param_grid = {
    "n_estimators": [50, 100, 200],
    "max_depth": [None, 5, 10],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4],
    "bootstrap": [True, False]
}

# %%
grid_search = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    cv=5,
    n_jobs=-1,
    scoring="accuracy",
    verbose=2
)

grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 162 candidates, totalling 810 fits
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.0s
# ...

# %%
print("Best Parameters:", grid_search.best_params_)
print("Best CV Accuracy:", grid_search.best_score_)
# Out:
# Best Parameters: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100}
# Best CV Accuracy: 0.8522857142857143

# %%
best_model = grid_search.best_estimator_
print("Test Accuracy:", best_model.score(X_test, y_test))
# Out:
# Test Accuracy: 0.859

# %%
joblib.dump(grid_search.best_estimator_, "../models/random_forest_model.pkl")
# Out:
# ['../models/random_forest_model.pkl']

# %%
# Test Loaded Model
loaded_model = joblib.load("../models/xgboost_model.pkl")
print("Sample Prediction:", loaded_model.predict([[14102.922471479013,4478.254022286159,181.34504548664012,81.45878813596623,41.0,3.1,113.86,98.45670655406815,2.46,831.9760323050034,76.06449854564227,46.290930350488146]]))
# Out:
# Sample Prediction: [1]
# /usr/lib/python3.12/pickle.py:1710: UserWarning: [18:56:03] WARNING: /workspace/src/collective/../data/../common/error_msg.h:82: If you are loading a serialized model (like pickle in Python, RDS in R) or
# configuration generated by an older version of XGBoost, please export the model by calling
# `Booster.save_model` from that version first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/stable/tutorials/saving_model.html
#
# for more details about differences between saving model and serializing.
#
#   setstate(state)
